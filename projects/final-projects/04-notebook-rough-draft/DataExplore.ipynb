# %%
import pandas as pd
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("../duckworth-grit-scale-data/cleanData.csv")

# %%
from matplotlib import pyplot

dims = (20, 20)
fig, ax = pyplot.subplots(figsize=dims)

#cols = [c for c in df.columns if (c.lower()[:8] != 'country_' or \
#        c == 'country_US') and 'os' not in c and 'screen' not in c and 'browser' not in c]
cols = [c for c in df.columns if (c.lower()[:8] != 'country_')]
dfCorr=df[cols]

corr = dfCorr.corr()
sns.heatmap(ax=ax,data=corr)

# %%
def get_agree_means(df):
    menDf = df[df['gender'] == 1]
    sample_of_sample = [np.random.choice(menDf['agreeableness'],size=len(menDf),replace=True)]
    return np.mean(sample_of_sample)

men_agree_means = [get_agree_means(df) for _ in range(10000)]
fig, ax = plt.subplots()
sns.distplot(men_agree_means)
ax.axvline(np.mean(df[df['gender'] == 1]['agreeableness']),linestyle='--',color='red')

# %%
def get_agree_means(df):
    menDf = df[df['gender'] == 0]
    sample_of_sample = [np.random.choice(menDf['agreeableness'],size=len(menDf),replace=True)]
    return np.mean(sample_of_sample)

men_agree_means = [get_agree_means(df) for _ in range(10000)]
fig, ax = plt.subplots()
sns.distplot(men_agree_means)
ax.axvline(np.mean(df[df['gender'] == 0]['agreeableness']),linestyle='--',color='red')

# %%
print np.mean(df['agreeableness'])
fig, ax = plt.subplots()
sns.distplot(df['agreeableness'])
ax.axvline(np.mean(df['agreeableness']),linestyle='--',color='red')
# Out:
# 38.4203081586

# %%
sns.distplot(df[df['gender'] == 1]['agreeableness'], label="men")
sns.distplot(df[df['gender'] == 0]['agreeableness'], label="women")

plt.legend()

# %%
df['agreeableness'].describe()
# Out:
# count    3959.000000
# mean       38.420308
# std         7.324994
# min        10.000000
# 25%        34.000000
# 50%        39.000000
# 75%        44.000000
# max        51.000000
# Name: agreeableness, dtype: float64

# %%
sns.distplot(df[df['gender'] == 1]['conscientiousness'], label="men")
sns.distplot(df[df['gender'] == 0]['conscientiousness'], label="women")

plt.legend()

# %%
df['grit'].corr(df['conscientiousness'])
# Out:
# 0.62167331839276352

# %%
df.head()
# Out:
#    Unnamed: 0  surveyelapse  education  gender  engnat   age  voted  \
# 0           0         174.0        4.0     0.0     0.0  28.0    1.0
# 1           1         120.0        2.0     0.0     1.0  19.0    0.0
# 2           3        5098.0        3.0     0.0     1.0  30.0    1.0
# 3           4         340.0        4.0     1.0     0.0  38.0    0.0
# 4           6         126.0        3.0     1.0     1.0  35.0    0.0
#
#    familysize  screenw  screenh  ...    orientation_other  race_asian  \
# 0         2.0   1366.0    768.0  ...                    0           0
# 1         3.0   1280.0    800.0  ...                    0           0
# 2         6.0   1600.0    900.0  ...                    0           0
# 3         3.0   1920.0   1080.0  ...                    0           1
# 4         1.0   1366.0    768.0  ...                    0           0
#
#    race_arab  race_black  race_white  race_other  married_never  \
# 0          0           0           1           0              1
# 1          0           0           1           0              1
# 2          0           1           0           0              1
# 3          0           0           0           0              0
# 4          0           0           1           0              0
#
#    married_currently  married_previously   liar
# 0                  0                   0  False
# 1                  0                   0   True
# 2                  0                   0  False
# 3                  1                   0  False
# 4                  0                   1  False
#
# [5 rows x 179 columns]
